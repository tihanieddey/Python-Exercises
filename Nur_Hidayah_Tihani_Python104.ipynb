# %% [markdown]
# # This exercise is to test your knowledge in
#
# 1.   Operators
# 2.   Decision making
# 3.   Loops
# 4.   Converting real world problems to mathematical expression
# 5.   Bitwise Operator

# %% [markdown]
# **Problem 1 FizzBuzz:**
#
# Write a program that prints the numbers from 1 to 100. But for multiples of three, print "Fizz" instead of the number, and for the multiples of five, print "Buzz". For numbers which are multiples of both three and five, print "FizzBuzz".

# %%
for num in range(1, 101):
  if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
  elif num % 3 == 0:
    print("Fizz")
  elif num % 5 == 0:
    print("Buzz")
  else:
    print(num)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# **Problem 2**
# **Collatz Sequence:**
#
# Write a program that takes an integer input from the user and generates the Collatz sequence for that number. The Collatz sequence is defined as follows:
#
# Start with a number n. If n is even, the next number is n/2. If n is odd, the next number is 3n + 1. Repeat the process until n becomes 1.

# %%
n = int(input("Enter an integer: "))

listnum = [n]

while n != 1:
  if n % 2 == 0:
    n = n // 2
  else:
    n = (3 * n) + 1
  listnum.append(n)

for num in listnum:
  print(num)
# Out:
# Enter an integer: 7
# 7
# 22
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# **Problem 3 GCD Calculation:**
#
# Write a program that takes two integers from the user and calculates their greatest common divisor (GCD) using the Euclidean algorithm.
#
# You can refer this Link
#
# https://www.khanacademy.org/computing/computer-science/cryptography/modarithmetic/a/the-euclidean-algorithm

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

while b != 0:
  a, b = b, a % b

print("Greatest Common Divisor for both number is ", a)

# %% [markdown]
# **Problem 4 Rock, Paper, Scissors:**
#
# Write a program that plays the game of Rock, Paper, Scissors with the user. The user makes a choice, the program randomly chooses, and the winner is determined.
#
# To generate random number use random module
#
# > import random
#
# > random.randint(1,3)

# %%
import random

comp_rand = random.randint(1,3)
list_rps = ("Rock", "Paper", "Scissor")

user_input = int(input("Enter number between 1 to 3 (1 for Rock, 2 for Paper, 3 for Scissor): "))

if (user_input in range(1,4)):
  print(f"You chose {list_rps[user_input - 1]}, computer chose {list_rps[comp_rand - 1]} ...")

  if (comp_rand == user_input):
    print("It's a tie!")
  else:
    if(comp_rand == 1 and user_input == 2):
      print("Paper beats Rock. You win!")
    elif(comp_rand == 1 and user_input == 3):
      print("Rock beats Scissor. You lose!")
    elif(comp_rand == 2 and user_input == 1):
      print("Paper beats Rock. You lose!")
    elif(comp_rand == 2 and user_input == 3):
      print("Scissor beats Paper. You win!")
    elif(comp_rand == 3 and user_input == 1):
      print("Rock beats Scissor. You win!")
    elif(comp_rand == 3 and user_input == 2):
      print("Scissor beats Paper. You lose!")

else:
  print("Error, you can only enter a number between 1 until 3")
# Out:
# Enter number between 1 to 3 (1 for Rock, 2 for Paper, 3 for Scissor): 3
# You chose Scissor, computer chose Scissor ...
# It's a tie!

# %% [markdown]
# **Problem 5 Number Guessing Game:**
#
# Write a program that randomly generates a number between 1 and 100. The user has to guess the number. After each guess, the program tells the user whether the guess is too high, too low, or correct. The game continues until the user guesses the correct number.
#
# To generate random number use random module
#
# > import random
#
# > random.randint(1,3)

# %%
import random

comp_rand = random.randint(1,100)
print("Guess a number between 1 to 100: ")

count = 1

while guess_num != comp_rand:
  count += 1

  guess_num = int(input("Your guess: "))

  if(comp_rand > guess_num):
    print("Try guess higher")
  elif(comp_rand < guess_num):
    print("Try guess lower")
  else:
    print(f"Congratulations! You guessed the number {comp_rand} correctly after {count} tries")
# Out:
# Guess a number between 1 to 100:
# Your guess: 45
# Try guess lower
# Your guess: 34
# Try guess higher
# Your guess: 37
# Try guess higher
# Your guess: 44
# Try guess lower
# Your guess: 40
# Try guess lower
# Your guess: 38
# Try guess higher
# Your guess: 39
# Congratulations! You guessed the number 39 correctly after 8 tries

# %% [markdown]
# **Problem 6 Perfect Number:**
# Write a program that generates 10 perfect numbers.
#
# Example
#
# 6: The divisors of 6 are 1, 2, 3, and 6. The sum of its proper divisors (excluding 6 itself) is 1 + 2 + 3 = 6.
#
# 28: The divisors of 28 are 1, 2, 4, 7, 14, and 28. The sum of its proper divisors (excluding 28 itself) is 1 + 2 + 4 + 7 + 14 = 28.

# %%
number = 1
count = 0

list_perfect = []

while count < 4 :
  sum = 0
  list_divisor = (num for num in range(1, number) if(number % num == 0))
  for num in list_divisor:
    sum += num
  if sum == number:
    list_perfect.append(number)
    count += 1
  number += 1

for number in list_perfect:
  print(number)
# Out:
# 6
# 28
# 496
# 8128

# %%
p = 2
perfect_numbers = []

count = 0

while count < 8:
       mersenne_prime = 2 ** p - 1
       is_prime = True
       if mersenne_prime <= 1:
         is_prime = False
       for i in range(2, int(mersenne_prime ** 0.5) + 1):
         if mersenne_prime % i == 0:
           is_prime = False

       if is_prime:
           perfect_number = 2 ** (p - 1) * mersenne_prime
           perfect_numbers.append(perfect_number)
           count += 1
       p += 1

for number in perfect_numbers:
  print(number)
# Out:
# 6
# 28
# 496
# 8128
# 33550336
# 8589869056
# 137438691328
# 2305843008139952128

# %% [markdown]
# **Problem 7 Harmonic Series:**
#
# Write a program that calculates the sum of the first n terms of the harmonic series. Take the n as Input.
#
# Hn = 1 +  1/2 + 1/3 + 1/4 .... + 1/n

# %%
n = int(input("Enter a positive number: "))

seq_sum = 0.0
i = 1

while i < (n + 1):
  seq_sum += 1 / i
  i += 1

print(f"{seq_sum:.2f}")
# Out:
# Enter a positive number: 5
# 2.28

# %% [markdown]
# **Problem 8 Number to Words:**
#
# Write a program that converts a number to its word representation (e.g., 123 to "one hundred twenty-three").

# %%
number = 123

ones = ["","one", "two", "three", "four", "five", "six", "seven", "eight", "nine",\
        "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen", "sixteen",\
        "seventeen", "eighteen", "nineteen"]
twos = ["", "", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]

result = ""

if number == 0:
  result = "zero"
else:
  if number >= 10000:
    if number // 1000 >= 20:
      result += twos[number // 10000] + " "
      number %= 10000
    result += ones[number // 1000] + " thousand "
    number %= 1000

  elif number >= 1000:
    result += ones[number // 1000] + " thousand "
    number %= 1000

  if number >= 100:
    result += ones[number // 100] + " hundred "
    number %= 100

  if number < 20:
    result += ones[number // 10]
  elif number >= 20:
    result += twos[number // 10]
    if number % 10 != 0:
      result += "-" + ones[number % 10]

print(result.strip())
# Out:
# one hundred twenty-three

# %% [markdown]
# **Problem 9 Roman to Integer**
#
# Write a program to convert a Roman numeral to an integer and also convert integer to Roman numeral

# %%
number = int(input("Enter roman numeral that you want to convert to integer: "))

values = [1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1]
symbols = ["M", "CM", "D", "CD", "C", "XC", "L", "XL", "X", "IX", "V", "IV", "I"]

roman = ""

count = 0

for val in values:
  count += 1

for i in range(count):
    while number >= values[i]:
        roman += symbols[i]
        number -= values[i]

print(f"The Roman numeral is: {roman}")
# Out:
# Enter roman numeral that you want to convert to integer: 191
# The Roman numeral is: CXCI

# %%
roman = input("Enter roman numerals that you want to change to number: ")

roman_numeral = {"M":1000, "D":500, "C":100, "L":50, "X":10, "V":5, "I":1}

total = 0

count = 0
for char in roman:
    count += 1

i = 0

while i < count:
  if i + 1 < count and roman_numeral[roman[i]] < roman_numeral[roman[i + 1]]:
    total += roman_numeral[roman[i + 1]] - roman_numeral[roman[i]]
    i += 2
  else:
    total += roman_numeral[roman[i]]
    i += 1

print(f"The number is: {total}")
# Out:
# Enter roman numerals that you want to change to number: CXCI
# The number is: 191

# %% [markdown]
# **Problem 10 String Compression**
#
# Write a program to perform basic string compression using the counts of repeated characters (e.g., "aabcccccaaa" -> "a2b1c5a3").

# %%
s = "aabcccccaaa"

count = 0
for char in s:
  count += 1

i = 0
while i < count:
  total = 1
  while i + 1 < count and s[i] == s[i + 1]:
    i += 1
    total += 1
  print(s[i] + str(total), end = "")
  i += 1
# Out:
# a2b1c5a3

# %% [markdown]
# **Problem 11: Laboratory Problem**
#
# A laboratory technician always needs to prepare various solutions.
#
# Coming Sunday, he has to create a 20-liter solution that is 35% salt by mixing two available solutions. One solution (A) is 25% salt, and the other solution (B) is 50% salt. How many liters of each solution are required to achieve the desired concentration?
#
# Coming Monday, he has to create an 8-liter solution that is 25% sugar by mixing two available solutions. One solution (A) is 15% sugar, and the other solution (B) is 40% sugar. How many liters of each solution are required to achieve the desired concentration?
#
# Write a simple, generic Python program to assist the laboratory technician. The program must take all these numbers (20 liters, 35, 25, 50) as input and calculate the required liters of each solution and print them. Please note that the same program must work for the second problem as well (8 liters, 25, 15, 40).
#
# The maximum stock for solution (A) and solution (B) is always 3 liter only. After calculating/printing the required quantity of A and B, throw proper message. For example, required quantity of solution (A) is less than 3 liter say "Solution (A) is available can proceed". If required quantity of solution (B) is greater than 3 liter say "Solution (B) is not available, please order 1.3 liter now".

# %%
vol = int(input("Enter the targeted solution: "))
salt_target = int(input("Enter targeted percentage solution: "))
per_a = int(input("Enter percentage solution A: "))
per_b = int(input("Enter percentage solution B: "))

per_target = salt_target / 100
a = per_a / 100
b = per_b / 100

# print(per_target, a, b)

x = (per_target - b) * vol / (a - b)
y = vol - x

print(f"Required quantity for solution A is {x:.2f}")
print(f"Required quantity for solution B is {y:.2f}")

if x < 3:
  print("Solution (A) is available, can proceed")
else:
  need = x - 3
  print(f"Solution (A) is not available, please order {need:.2f} liter now")

if y < 3:
  print("Solution (B) is available, can proceed")
else:
  need = y - 3
  print(f"Solution (B) is not available, please order {need:.2f} liter now")
# Out:
# Enter the targeted solution: 20
# Enter targeted percentage solution: 35
# Enter percentage solution A: 25
# Enter percentage solution B: 50
# Required quantity for solution A is 12.00
# Required quantity for solution B is 8.00
# Solution (A) is not available, please order 9.00 liter now
# Solution (B) is not available, please order 5.00 liter now

# %%
vol = int(input("Enter the targeted solution: "))
salt_target = int(input("Enter targeted percentage solution: "))
per_a = int(input("Enter percentage solution A: "))
per_b = int(input("Enter percentage solution B: "))

per_target = salt_target / 100
a = per_a / 100
b = per_b / 100

# print(per_target, a, b)

x = (per_target - b) * vol / (a - b)
y = vol - x

print(f"Required quantity for solution A is {x:.2f}")
print(f"Required quantity for solution B is {y:.2f}")

if x < 3:
  print("Solution (A) is available, can proceed")
else:
  need = x - 3
  print(f"Solution (A) is not available, please order {need:.2f} liter now")

if y < 3:
  print("Solution (B) is available, can proceed")
else:
  need = y - 3
  print(f"Solution (B) is not available, please order {need:.2f} liter now")
# Out:
# Enter the targeted solution: 8
# Enter targeted percentage solution: 25
# Enter percentage solution A: 15
# Enter percentage solution B: 40
# Required quantity for solution A is 4.80
# Required quantity for solution B is 3.20
# Solution (A) is not available, please order 1.80 liter now
# Solution (B) is not available, please order 0.20 liter now

# %% [markdown]
# **Problem 12:**
#
# Initialize two variables, x = 0b10101100 and y = 0b11011001.
#
# Write Python code to:
# 1. Extract the lower 4 bits from x.
# 2. Check if y is even or odd.
# 3. Clear the upper 4 bits of x.
# 4. Check if the 5th bit of y is set.

# %%
x = 0b10101100
y = 0b11011001

lower_bit_x = x & 0b00001111
print("The lower 4 bits from x: ", bin(lower_bit_x))

even_y = (y % 2 == 0)
print("y is even: ", even_y)

upper_bit_x = x & 0b00001111
print("Cleared upper 4 bit of x: ", bin(upper_bit_x))

fifth_bit_set = (y & 0b00100000) != 0
print("5th bit of y is a set: ", fifth_bit_set)
# Out:
# The lower 4 bits from x:  0b1100
# y is even:  False
# Cleared upper 4 bit of x:  0b1100
# 5th bit of y is a set:  False

# %% [markdown]
# **Problem 13: Construction Problem**
#
# A construction project requires two workers to complete. Worker A can complete the project in 12 hours, while Worker B can complete the same project in 16 hours. How long will it take for both workers to complete the project if they work together?
#
# Another project requires Worker C, who can complete it in 8 hours, and Worker D, who can complete it in 10 hours. How long will it take for both workers to complete this project if they work together?
#
# Write a simple, generic Python program to assist in calculating the time required for two workers to complete a project when working together. The program must take all these numbers (12, 16) as input and calculate the required time. Finally, print the result. Please note that the same program must work for the second problem as well (8, 10).

# %%
time1 = int(input("Enter rate hour worker A: "))
time2 = int(input("Enter rate hour worker B: "))

total_hour = (1 / time1) + (1 / time2)
hour = int(1 // total_hour)
minute = int(((1 / total_hour) - hour) * 60)

print(f"The project can be completed in {hour} hours and {minute} minutes")
# Out:
# Enter rate hour worker A: 12
# Enter rate hour worker B: 16
# The project can be completed in 6 hours and 51 minutes

# %%
time1 = int(input("Enter rate hour worker A: "))
time2 = int(input("Enter rate hour worker B: "))

total_hour = (1 / time1) + (1 / time2)
hour = int(1 // total_hour)
minute = int(((1 / total_hour) - hour) * 60)

print(f"The project can be completed in {hour} hours and {minute} minutes")
# Out:
# Enter rate hour worker A: 8
# Enter rate hour worker B: 10
# The project can be completed in 4 hours and 26 minutes

# %% [markdown]
# **Problem 14:**
#
# Initialize two variables, a = 0b10101000 and b = 0b01010100.
#
# Write Python code to:
# 1. Set the lower 4 bits of a.
# 2. Combine the bits of a and b using OR.
# 3. Create a mask to set the 2nd and 6th bits of a.

# %%
a = 0b10101000
b = 0b01010100

lower_bit_a = a & 0b00001111
print("Lower bit of a: ", bin(lower_bit_a))

comb_a_b = a | b
print("Combination of a and b: ", bin(comb_a_b))

sec_set = 0b00000100
six_set = 0b01000000

mask_bit_a = sec_set | six_set

mask_sec_a = a | mask_bit_a
print("a with 2nd and 6th set: ", bin(mask_sec_a))
# Out:
# Lower bit of a:  0b1000
# Combination of a and b:  0b11111100
# a with 2nd and 6th set:  0b11101100

# %% [markdown]
# **Problem 15: Investor Problem**
#
# An investor decides to invest a total of RM30,000 in two different accounts. The first account offers a 5% annual interest rate, while the second account offers a 7% annual interest rate. If the total annual interest earned is RM1,800, how much money was invested in each account?
#
# Another investor decides to invest a total of RM50,000 in two different accounts. The first account offers a 3% annual interest rate, while the second account offers a 6% annual interest rate. If the total annual interest earned is RM2,400, how much money was invested in each account?
#
# Write a simple, generic Python program to assist in calculating the amount of money invested in each account to achieve the desired total annual interest. The program must take all these numbers (30000, 5, 7, 1800) as input and calculate the required amounts. Finally, print the result. Please note that the same program must work for the second problem as well (50000, 3, 6, 2400).

# %%
total_invest = float(input("Enter total invest in RM: "))
rate1 = float(input("Enter annual rate for first account in (%): "))
rate2 = float(input("Enter annual rate for second account in (%): "))
total_annual = float(input("Enter total annual interest earned in RM: "))

rate1 = rate1 / 100
rate2 = rate2 / 100

difference_rate = rate1 - rate2

x = (total_annual - (rate2 * total_invest)) / difference_rate
y = total_invest - x

print(f"Amount invested on first account: RM{x:.2f}")
print(f"Amount invested on second account: RM{y:.2f}")
# Out:
# Enter total invest in RM: 30000
# Enter annual rate for first account in (%): 5
# Enter annual rate for second account in (%): 7
# Enter total annual interest earned in RM: 1800
# Amount invested on first account: RM15000.00
# Amount invested on second account: RM15000.00

# %%
total_invest = float(input("Enter total invest in RM: "))
rate1 = float(input("Enter annual rate for first account in (%): "))
rate2 = float(input("Enter annual rate for second account in (%): "))
total_annual = float(input("Enter total annual interest earned in RM: "))

rate1 = rate1 / 100
rate2 = rate2 / 100

difference_rate = rate1 - rate2

x = (total_annual - (rate2 * total_invest)) / difference_rate
y = total_invest - x

print(f"Amount invested on first account: RM{x:.2f}")
print(f"Amount invested on second account: RM{y:.2f}")
# Out:
# Enter total invest in RM: 50000
# Enter annual rate for first account in (%): 3
# Enter annual rate for second account in (%): 6
# Enter total annual interest earned in RM: 2400
# Amount invested on first account: RM20000.00
# Amount invested on second account: RM30000.00

# %% [markdown]
# **Problem 16:**
#
# Initialize two variables, x = 0b10101100 and y = 0b11010010.
#
# Write Python code to:
# 1. Swap the values of x and y without using a temporary variable.
# 2. Toggle the 3rd and 5th bits of x.
# 3. Check if two given numbers a = 29 and b = 15 are different.

# %%
x = 0b10101100
y = 0b11010010

x = x ^ y
y = x ^ y
x = x ^ y
print("Swapped x: ", bin(x))
print("Swapped y: ", bin(y))
# Out:
# Swapped x:  0b11010010
# Swapped y:  0b10101100

# %%
x = 0b10101100

x_fifth = 0b00100000
x_third = 0b00001000

mask_x = x_fifth | x_third
toggled_x = x ^ mask_x
print("Toggled x: ", bin(toggled_x))
# Out:
# Toggled x:  0b10000100

# %%
a = 29
b = 15

different = (a ^ b != 0)
if different:
  print(f"{a} and {b} are different")
else:
  print(f"{a} and {b} are the same")
# Out:
# 29 and 15 are different

# %% [markdown]
# **Problem 17: LCM of 2 Numbers**
#
# Finding the LCM of Two Numbers
# Write a Python program that finds the least common multiple (LCM) of two numbers.
#
# Example:
#
# Input: a = 4, b = 6
# Output: LCM = 12

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

n1 = a
n2 = b

while n2 != 0:
  n1, n2 = n2, n1 % n2

lcm_num = int(abs(a * b) / n1)

print("Least Common Multiple for both number is ", lcm_num)
# Out:
# Enter first number: 4
# Enter second number: 6
# Least Common Multiple for both number is  12

# %% [markdown]
# **Problem 18: Sum of Series**
#
# Finding the Sum of a Series
# Write a Python program that finds the sum of the series
# 1 ^ 2 + 2 ^ 2 + 3 ^ 2 + ... + 𝑛 ^ 2
#
# Example:
#
# Input: n = 5
# Output: Sum = 55

# %%
n = int(input("Enter a number:"))

sum_num = 0
i = 0

while i < (n + 1):
   sum_num = sum_num + (i ** 2)
   i += 1

print(sum_num)
# Out:
# Enter a number:5
# 55

# %% [markdown]
# **Problem 19: Distance**
#
#
# Write a Python program that calculates the distance between a point (x0,y0) and a line given by the equation ax + by + c=0.
#
# Example:
#
# Input: x0 = 3, y0 = 4, a = 1, b = -2, c = -1
# Output: Distance = 4.47
#
# ![image.png](data:image/png;base64,...)

# %%
x0 = int(input("Enter the x coordinate of the point, x0: "))
y0 = int(input("Enter the y coordinate of the point, y0: "))
a = int(input("Enter the coefficient of x in the line equation, a: "))
b = int(input("Enter the coefficient of y in the line equation, b: "))
c = int(input("Enter the constant term in the line equation, c: "))

distance = abs((a * x0 + b * y0 + c)) / ((a ** 2 + b ** 2) ** 0.5)

print(f"The distance from the point to the line is: {distance:.2f}")
# Out:
# Enter the x coordinate of the point, x0: 3
# Enter the y coordinate of the point, y0: 4
# Enter the coefficient of x in the line equation, a: 1
# Enter the coefficient of y in the line equation, b: -2
# Enter the constant term in the line equation, c: -1
# The distance from the point to the line is: 2.68

# %% [markdown]
# **Problem 20: Solving Cubic Equation**
#
# Write a Python program to solve a cubic equation of the form
# ax^3 + bx^2 + cx + d = 0.
#
# Example:
#
# Input: a = 1, b = -6, c = 11, d = -6
# Output: Roots are 1.0, 2.0, and 3.0

# %%
a = int(input("Enter the coefficient of x^3: "))
b = int(input("Enter the coefficient of x^2: "))
c = int(input("Enter the coefficient of x: "))
d = int(input("Enter the constant term: "))

roots = []

for x in range(-10, 11):
  cubic_eq = (a * (x ** 3)) + (b * (x ** 2)) + (c * x) + d
  if cubic_eq == 0:
    roots.append(x)

print("Roots for this equation are: ")
for num in roots:
  print(float(num))
# Out:
# Enter the coefficient of x^3: 1
# Enter the coefficient of x^2: -6
# Enter the coefficient of x: 11
# Enter the constant term: -6
# Roots for this equation are:
# 1.0
# 2.0
# 3.0
